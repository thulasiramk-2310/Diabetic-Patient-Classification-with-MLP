# %%
# importing required libraries
import numpy as np  # nd-arrays
import pandas as pd  # read data from datasources
from sklearn.preprocessing import LabelEncoder  # Encode categorical variables
from sklearn.preprocessing import StandardScaler  # Standardize the data using mean and std
from sklearn.model_selection import train_test_split  # split the data into train and test
from sklearn.metrics import accuracy_score, confusion_matrix  # evaluate a model
from sklearn.neural_network import MLPClassifier  # build a model using MLP
from sklearn.model_selection import GridSearchCV  # tune the hyperparameters
from sklearn.metrics import average_precision_score, make_scorer, recall_score  # custom scoring functions

# %%
# Reading the data into dataframe
diabetes_df = pd.read_excel('data_file.xlsx')
diabetes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2703 entries, 0 to 2702
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   GENDER    2703 non-null   int64
#  1   AGE       2703 non-null   int64
#  2   Height    2703 non-null   int64
#  3   Weight    2703 non-null   float64
#  4   BMI       2703 non-null   float64
#  5   BAI       2703 non-null   float64
#  6   HBA1C1    2703 non-null   float64
#  7   OGTT1FBS  2703 non-null   int64
#  8   NDD       2703 non-null   int64
# dtypes: float64(4), int64(5)
# memory usage: 190.2 KB

# %%
# Work on a copy of the dataset
clean_df = diabetes_df.copy()

# Prune the data by removing duplicates
clean_df.drop_duplicates(keep='first', inplace=True)

print(clean_df.shape)
# Out:
# (1065, 9)

# %%
clean_df.head(1)
# Out:
#    GENDER  AGE  Height  Weight        BMI    BAI  HBA1C1  OGTT1FBS  NDD
# 0       1   37     156    88.0  36.160421  41.53     5.1       102    0

# %%
# Assign labels with appropriate numerics
nondia = -1
diabetic = 1

# Create a column to indicate diabetic status based on NDD
Ynew = pd.DataFrame(np.where(clean_df['NDD'] == 1, diabetic, nondia), index=clean_df.index, columns=['diabetic'])

# %%
# Identify the diabetic status of each record using the blood test results of FBS or HBA1C1
Ynew.loc[(clean_df.OGTT1FBS >= 126) | (clean_df.HBA1C1 >= 6.5), 'diabetic'] = diabetic

# Concatenate the diabetic status with the anthropometric features of the dataset
data_df = pd.concat([clean_df.iloc[:, :6], Ynew], axis=1)

# %%
data_df.head(1)
# Out:
#    GENDER  AGE  Height  Weight        BMI    BAI  diabetic
# 0       1   37     156    88.0  36.160421  41.53        -1

# %%
# Find the diabetic and non-diabetic patients
diabetic_yes = data_df[data_df.diabetic == diabetic]
diabetic_no = data_df[data_df.diabetic == nondia]

# %%
diabetic_yes.describe()
# Out:
#            GENDER         AGE      Height      Weight         BMI         BAI  \
# count  556.000000  556.000000  556.000000  556.000000  556.000000  556.000000
# mean     0.566547   51.624101  160.210432   68.321942   26.628727   29.641799
# std      0.495998   10.930447    7.564781   12.714347    4.776916    7.802823
# min      0.000000   25.000000  138.000000   35.000000   13.671875    8.300000
# 25%      0.000000   43.000000  156.000000   59.750000   23.434014   24.790000
# 50%      1.000000   50.000000  159.000000   68.000000   26.562500   28.145000
# 75%      1.000000   59.000000  165.000000   76.000000   29.585799   33.872500
# max      1.000000   80.000000  186.000000  102.000000   41.207076   58.250000
#
#        diabetic
# count     556.0
# mean        1.0
# std         0.0
# min         1.0
# 25%         1.0
# 50%         1.0
# 75%         1.0
# max         1.0

# %%
diabetic_no.describe()
# Out:
#            GENDER         AGE      Height      Weight         BMI         BAI  \
# count  509.000000  509.000000  509.000000  509.000000  509.000000  509.000000
# mean     0.449902   44.265226  158.180747   68.411591   27.307721   31.775776
# std      0.497973   11.931332    7.952290   13.186206    4.798944    8.245442
# min      0.000000   20.000000  139.000000   33.500000   14.888889   14.080000
# 25%      0.000000   35.000000  153.000000   61.000000   24.508946   25.650000
# 50%      0.000000   44.000000  158.000000   68.000000   26.959840   30.340000
# 75%      1.000000   52.000000  162.000000   76.000000   30.043262   38.260000
# max      1.000000   84.000000  186.000000  110.000000   50.219138   59.760000
#
#        diabetic
# count     509.0
# mean       -1.0
# std         0.0
# min        -1.0
# 25%        -1.0
# 50%        -1.0
# 75%        -1.0
# max        -1.0

# %%
train_x, test_x, train_y, test_y = train_test_split(data_df.iloc[:,:6],
 data_df.diabetic,
 test_size=0.3, random_state=43)

# %%
sc = StandardScaler()  # creating an instance for StandardScaler class
train_x = sc.fit_transform(train_x)  # estimate mu and sigma for train set and transform
test_x = sc.transform(test_x)  # transform the test set

# %%
# fetch the diabetic records from train set
diabetic_yes_train = train_x[list(np.where(train_y == diabetic)[0])]
# fetch the non-diabetic records from train set
diabetic_no_train = train_x[list(np.where(train_y == nondia)[0])]
# display the counts for each class
print('non-diabetic=', diabetic_no_train.shape, 'diabetic=', diabetic_yes_train.shape)
# Out:
# non-diabetic= (347, 6) diabetic= (398, 6)

# %%
# fetch the diabetic records from test set
diabetic_yes_test = test_x[list(np.where(test_y == diabetic)[0])]
# fetch the non-diabetic records from test set
diabetic_no_test = test_x[list(np.where(test_y == nondia)[0])]
# display the counts for each class from test set
print('non-diabetic=', diabetic_no_test.shape, 'diabetic=', diabetic_yes_test.shape)
# Out:
# non-diabetic= (162, 6) diabetic= (158, 6)

# %%
# Evaluate a model using confusion matrix and accuracy score between true and actual
def evaluate(yt, yp):
    cf = confusion_matrix(yt, yp)  # estimate confusion matrix
    acc = accuracy_score(yt, yp)   # estimate accuracy of the model
    return cf, acc

# %%
# Display metrics
def display(yt, yp, model):
    cf, acc = evaluate(yt, yp)
    print('Model =', model, '\ncf =', cf, '\nacc =', acc, '\n')

# %%
# Perform Classification using MLP Classifier
mlpc = MLPClassifier(hidden_layer_sizes=1, activation='tanh',
                    learning_rate='invscaling', max_iter=10000,
                    solver='sgd', random_state=0, early_stopping=True)  # create a MLPClassifier instance
mlpc.fit(train_x, train_y)  # fit the model for trainset
train_yp = mlpc.predict(train_x)  # predict the y for train set
test_yp = mlpc.predict(test_x)  # predict the y for test set

# %%
# display the results
display(train_y,train_yp,'MLP: Training')
display(test_y,test_yp,'MLP: Testing')
# Out:
# Model = MLP: Training
# cf = [[  0 347]
#  [  0 398]]
# acc = 0.5342281879194631
#
# Model = MLP: Testing
# cf = [[  0 162]
#  [  0 158]]
# acc = 0.49375

# %%
mlpc.classes_
# Out:
# array([-1,  1])

# %%
mlpc.loss_
# Out:
# np.float64(0.8298330075915282)

# %%
mlpc.coefs_
# Out:
# [array([[ 0.09045038],
#         [ 0.39957265],
#         [ 0.19025382],
#         [ 0.08227145],
#         [-0.14222192],
#         [ 0.26913367]]),
#  array([[1.35776874]])]

# %%
mlpc.intercepts_
# Out:
# [array([-0.11892174]), array([1.6030463])]

# %%
mlpc.n_layers_
# Out:
# 3

# %%
mlpc.n_iter_
# Out:
# 12

# %%
mlpc.n_outputs_
# Out:
# 1

# %%
mlpc.out_activation_
# Out:
# 'logistic'

# %%
 # recall = tp / (tp + fn) = Sensitivity or True Positive Rate / True Negative Rate
 # precision = tp / (tp + fp) = Positive predictive value
custom_scorer = {'recall':make_scorer(recall_score, pos_label=diabetic),
 'precision':make_scorer(average_precision_score, pos_label=diabetic)}

# %%
gscv = GridSearchCV(MLPClassifier(max_iter=10000,random_state=0),
                    { 'activation':('tanh','logistic','relu'),
 'hidden_layer_sizes':range(1,4,1),'solver':['adam','sgd']}, 
cv=5,verbose=False,
 scoring=custom_scorer,refit='recall')
gscv.fit(train_x,train_y)
gscv.best_params_
# Out:
# {'activation': 'logistic', 'hidden_layer_sizes': 1, 'solver': 'adam'}

# %%
 #Perform Classification using MLP Classifier
mlpc = MLPClassifier(hidden_layer_sizes=(1),activation='logistic',
 max_iter=10000,
 solver='adam',
 random_state=0) # create a MLPClassifier instance
mlpc.fit(train_x, train_y) # fit the model for trainset
train_yp=mlpc.predict(train_x) # predict the y for train set
test_yp=mlpc.predict(test_x) # predict the y for test set
 # display the results
display(train_y,train_yp,'MLP with "sgd" solver and 1,4 hidden nodes')
display(test_y,test_yp,'For Testing')
# Out:
# Model = MLP with "sgd" solver and 1,4 hidden nodes
# cf = [[  0 347]
#  [  0 398]]
# acc = 0.5342281879194631
#
# Model = For Testing
# cf = [[  0 162]
#  [  0 158]]
# acc = 0.49375

# %%
mlpc.coefs_
# Out:
# [array([[ 0.42498821],
#         [ 1.14677073],
#         [ 0.43369027],
#         [-0.09980984],
#         [-0.32748723],
#         [-0.30029026]]),
#  array([[0.54230605]])]

# %%
mlpc.intercepts_
# Out:
# [array([-0.53333804]), array([0.04664223])]

# %%
mlpc.score(test_x, test_y)
# Out:
# 0.49375

# %% [markdown]
# ## Improving MLP Model Performance
#
# The current accuracy is low. Let's try the following strategies:
# - Tune hyperparameters using GridSearchCV
# - Try different activation functions, solvers, and hidden layer sizes
# - Evaluate with confusion matrix and accuracy
# - Optionally, try other classifiers for comparison

# %%
# Hyperparameter tuning with GridSearchCV
param_grid = {
    'hidden_layer_sizes': [(1,), (2,), (3,), (4,), (5,), (10,), (20,)],
    'activation': ['tanh', 'relu', 'logistic'],
    'solver': ['adam', 'sgd'],
    'learning_rate': ['constant', 'invscaling', 'adaptive'],
    'max_iter': [1000, 5000, 10000]
}
gscv = GridSearchCV(MLPClassifier(random_state=0), param_grid, cv=5, scoring='accuracy', verbose=2)
gscv.fit(train_x, train_y)
print('Best parameters:', gscv.best_params_)
print('Best cross-validated score:', gscv.best_score_)

# Evaluate best model on test set
best_mlp = gscv.best_estimator_
test_pred = best_mlp.predict(test_x)
from sklearn.metrics import confusion_matrix, accuracy_score
print('Test accuracy:', accuracy_score(test_y, test_pred))
print('Confusion matrix:\n', confusion_matrix(test_y, test_pred))
# Out:
# Fitting 5 folds for each of 378 candidates, totalling 1890 fits
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=constant, max_iter=1000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=constant, max_iter=1000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=constant, max_iter=1000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=constant, max_iter=1000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=constant, max_iter=1000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=constant, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=constant, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=constant, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=constant, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=constant, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=constant, max_iter=5000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=constant, max_iter=5000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=constant, max_iter=5000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=constant, max_iter=5000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=constant, max_iter=5000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=constant, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=constant, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=constant, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=constant, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=constant, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=constant, max_iter=10000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=constant, max_iter=10000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=constant, max_iter=10000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=constant, max_iter=10000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=constant, max_iter=10000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=constant, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=constant, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=constant, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=constant, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=constant, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=invscaling, max_iter=1000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=invscaling, max_iter=1000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=invscaling, max_iter=1000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=invscaling, max_iter=1000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=invscaling, max_iter=1000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=invscaling, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=invscaling, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=invscaling, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=invscaling, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=invscaling, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=invscaling, max_iter=5000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=invscaling, max_iter=5000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=invscaling, max_iter=5000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=invscaling, max_iter=5000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=invscaling, max_iter=5000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=invscaling, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=invscaling, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=invscaling, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=invscaling, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=invscaling, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=invscaling, max_iter=10000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=invscaling, max_iter=10000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=invscaling, max_iter=10000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=invscaling, max_iter=10000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=invscaling, max_iter=10000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=invscaling, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=invscaling, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=invscaling, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=invscaling, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=invscaling, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=adaptive, max_iter=1000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=adaptive, max_iter=1000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=adaptive, max_iter=1000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=adaptive, max_iter=1000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=adaptive, max_iter=1000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=adaptive, max_iter=1000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=adaptive, max_iter=1000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=adaptive, max_iter=1000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=adaptive, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=adaptive, max_iter=1000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=adaptive, max_iter=5000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=adaptive, max_iter=5000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=adaptive, max_iter=5000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=adaptive, max_iter=5000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=adaptive, max_iter=5000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=adaptive, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=adaptive, max_iter=5000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=adaptive, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=adaptive, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=adaptive, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=adaptive, max_iter=10000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=adaptive, max_iter=10000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=adaptive, max_iter=10000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=adaptive, max_iter=10000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=adaptive, max_iter=10000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=adaptive, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=adaptive, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=adaptive, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=adaptive, max_iter=10000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(1,), learning_rate=adaptive, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=constant, max_iter=1000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=constant, max_iter=1000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=constant, max_iter=1000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=constant, max_iter=1000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=constant, max_iter=1000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=constant, max_iter=1000, solver=sgd; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=constant, max_iter=1000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=constant, max_iter=1000, solver=sgd; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=constant, max_iter=1000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=constant, max_iter=1000, solver=sgd; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=constant, max_iter=5000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=constant, max_iter=5000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=constant, max_iter=5000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=constant, max_iter=5000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=constant, max_iter=5000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=constant, max_iter=5000, solver=sgd; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=constant, max_iter=5000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=constant, max_iter=5000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=constant, max_iter=5000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=constant, max_iter=5000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=constant, max_iter=10000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=constant, max_iter=10000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=constant, max_iter=10000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=constant, max_iter=10000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=constant, max_iter=10000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=constant, max_iter=10000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=constant, max_iter=10000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=constant, max_iter=10000, solver=sgd; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=constant, max_iter=10000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=constant, max_iter=10000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=invscaling, max_iter=1000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=invscaling, max_iter=1000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=invscaling, max_iter=1000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=invscaling, max_iter=1000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=invscaling, max_iter=1000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=invscaling, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=invscaling, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=invscaling, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=invscaling, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=invscaling, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=invscaling, max_iter=5000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=invscaling, max_iter=5000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=invscaling, max_iter=5000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=invscaling, max_iter=5000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=invscaling, max_iter=5000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=invscaling, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=invscaling, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=invscaling, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=invscaling, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=invscaling, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=invscaling, max_iter=10000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=invscaling, max_iter=10000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=invscaling, max_iter=10000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=invscaling, max_iter=10000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=invscaling, max_iter=10000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=invscaling, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=invscaling, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=invscaling, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=invscaling, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=invscaling, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=adaptive, max_iter=1000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=adaptive, max_iter=1000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=adaptive, max_iter=1000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=adaptive, max_iter=1000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=adaptive, max_iter=1000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=adaptive, max_iter=1000, solver=sgd; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=adaptive, max_iter=1000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=adaptive, max_iter=1000, solver=sgd; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=adaptive, max_iter=1000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=adaptive, max_iter=1000, solver=sgd; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=adaptive, max_iter=5000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=adaptive, max_iter=5000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=adaptive, max_iter=5000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=adaptive, max_iter=5000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=adaptive, max_iter=5000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=adaptive, max_iter=5000, solver=sgd; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=adaptive, max_iter=5000, solver=sgd; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=adaptive, max_iter=5000, solver=sgd; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=adaptive, max_iter=5000, solver=sgd; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=adaptive, max_iter=5000, solver=sgd; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=adaptive, max_iter=10000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=adaptive, max_iter=10000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=adaptive, max_iter=10000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=adaptive, max_iter=10000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=adaptive, max_iter=10000, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=adaptive, max_iter=10000, solver=sgd; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=adaptive, max_iter=10000, solver=sgd; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=adaptive, max_iter=10000, solver=sgd; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=adaptive, max_iter=10000, solver=sgd; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(2,), learning_rate=adaptive, max_iter=10000, solver=sgd; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=constant, max_iter=1000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=constant, max_iter=1000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=constant, max_iter=1000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=constant, max_iter=1000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=constant, max_iter=1000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=constant, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=constant, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=constant, max_iter=1000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=constant, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=constant, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=constant, max_iter=5000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=constant, max_iter=5000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=constant, max_iter=5000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=constant, max_iter=5000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=constant, max_iter=5000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=constant, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=constant, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=constant, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=constant, max_iter=5000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=constant, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=constant, max_iter=10000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=constant, max_iter=10000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=constant, max_iter=10000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=constant, max_iter=10000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=constant, max_iter=10000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=constant, max_iter=10000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=constant, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=constant, max_iter=10000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=constant, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=constant, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=invscaling, max_iter=1000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=invscaling, max_iter=1000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=invscaling, max_iter=1000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=invscaling, max_iter=1000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=invscaling, max_iter=1000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=invscaling, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=invscaling, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=invscaling, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=invscaling, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=invscaling, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=invscaling, max_iter=5000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=invscaling, max_iter=5000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=invscaling, max_iter=5000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=invscaling, max_iter=5000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=invscaling, max_iter=5000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=invscaling, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=invscaling, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=invscaling, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=invscaling, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=invscaling, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=invscaling, max_iter=10000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=invscaling, max_iter=10000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=invscaling, max_iter=10000, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=invscaling, max_iter=10000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=invscaling, max_iter=10000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=invscaling, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=invscaling, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=invscaling, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=invscaling, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=invscaling, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=adaptive, max_iter=1000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=adaptive, max_iter=1000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=adaptive, max_iter=1000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=adaptive, max_iter=1000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=adaptive, max_iter=1000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=adaptive, max_iter=1000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=adaptive, max_iter=1000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=adaptive, max_iter=1000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=adaptive, max_iter=1000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=adaptive, max_iter=1000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=adaptive, max_iter=5000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=adaptive, max_iter=5000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=adaptive, max_iter=5000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=adaptive, max_iter=5000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=adaptive, max_iter=5000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=adaptive, max_iter=5000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=adaptive, max_iter=5000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=adaptive, max_iter=5000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=adaptive, max_iter=5000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=adaptive, max_iter=5000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=adaptive, max_iter=10000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=adaptive, max_iter=10000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=adaptive, max_iter=10000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=adaptive, max_iter=10000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=adaptive, max_iter=10000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=adaptive, max_iter=10000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=adaptive, max_iter=10000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=adaptive, max_iter=10000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=adaptive, max_iter=10000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(3,), learning_rate=adaptive, max_iter=10000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=constant, max_iter=1000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=constant, max_iter=1000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=constant, max_iter=1000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=constant, max_iter=1000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=constant, max_iter=1000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=constant, max_iter=1000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=constant, max_iter=1000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=constant, max_iter=1000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=constant, max_iter=1000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=constant, max_iter=1000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=constant, max_iter=5000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=constant, max_iter=5000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=constant, max_iter=5000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=constant, max_iter=5000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=constant, max_iter=5000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=constant, max_iter=5000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=constant, max_iter=5000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=constant, max_iter=5000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=constant, max_iter=5000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=constant, max_iter=5000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=constant, max_iter=10000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=constant, max_iter=10000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=constant, max_iter=10000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=constant, max_iter=10000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=constant, max_iter=10000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=constant, max_iter=10000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=constant, max_iter=10000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=constant, max_iter=10000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=constant, max_iter=10000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=constant, max_iter=10000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=invscaling, max_iter=1000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=invscaling, max_iter=1000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=invscaling, max_iter=1000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=invscaling, max_iter=1000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=invscaling, max_iter=1000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=invscaling, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=invscaling, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=invscaling, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=invscaling, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=invscaling, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=invscaling, max_iter=5000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=invscaling, max_iter=5000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=invscaling, max_iter=5000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=invscaling, max_iter=5000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=invscaling, max_iter=5000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=invscaling, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=invscaling, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=invscaling, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=invscaling, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=invscaling, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=invscaling, max_iter=10000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=invscaling, max_iter=10000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=invscaling, max_iter=10000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=invscaling, max_iter=10000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=invscaling, max_iter=10000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=invscaling, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=invscaling, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=invscaling, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=invscaling, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=invscaling, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=adaptive, max_iter=1000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=adaptive, max_iter=1000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=adaptive, max_iter=1000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=adaptive, max_iter=1000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=adaptive, max_iter=1000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=adaptive, max_iter=1000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=adaptive, max_iter=1000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=adaptive, max_iter=1000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=adaptive, max_iter=1000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=adaptive, max_iter=1000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=adaptive, max_iter=5000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=adaptive, max_iter=5000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=adaptive, max_iter=5000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=adaptive, max_iter=5000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=adaptive, max_iter=5000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=adaptive, max_iter=5000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=adaptive, max_iter=5000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=adaptive, max_iter=5000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=adaptive, max_iter=5000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=adaptive, max_iter=5000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=adaptive, max_iter=10000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=adaptive, max_iter=10000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=adaptive, max_iter=10000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=adaptive, max_iter=10000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=adaptive, max_iter=10000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=adaptive, max_iter=10000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=adaptive, max_iter=10000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=adaptive, max_iter=10000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=adaptive, max_iter=10000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(4,), learning_rate=adaptive, max_iter=10000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(5,), learning_rate=constant, max_iter=1000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5,), learning_rate=constant, max_iter=1000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5,), learning_rate=constant, max_iter=1000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5,), learning_rate=constant, max_iter=1000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5,), learning_rate=constant, max_iter=1000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5,), learning_rate=constant, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5,), learning_rate=constant, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5,), learning_rate=constant, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5,), learning_rate=constant, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5,), learning_rate=constant, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5,), learning_rate=constant, max_iter=5000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5,), learning_rate=constant, max_iter=5000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5,), learning_rate=constant, max_iter=5000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5,), learning_rate=constant, max_iter=5000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5,), learning_rate=constant, max_iter=5000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5,), learning_rate=constant, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5,), learning_rate=constant, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5,), learning_rate=constant, max_iter=5000, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(5,), learning_rate=constant, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5,), learning_rate=constant, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5,), learning_rate=constant, max_iter=10000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5,), learning_rate=constant, max_iter=10000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5,), learning_rate=constant, max_iter=10000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5,), learning_rate=constant, max_iter=10000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5,), learning_rate=constant, max_iter=10000, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5,), learning_rate=constant, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5,), learning_rate=constant, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5,), learning_rate=constant, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5,), learning_rate=constant, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5,), learning_rate=constant, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5,), learning_rate=invscaling, max_iter=1000, solver=adam; total time=   0.0s
# ...
# [CV] END activation=logistic, hidden_layer_sizes=(10,), learning_rate=invscaling, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(10,), learning_rate=invscaling, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(10,), learning_rate=invscaling, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(10,), learning_rate=adaptive, max_iter=1000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(10,), learning_rate=adaptive, max_iter=1000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(10,), learning_rate=adaptive, max_iter=1000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(10,), learning_rate=adaptive, max_iter=1000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(10,), learning_rate=adaptive, max_iter=1000, solver=adam; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(10,), learning_rate=adaptive, max_iter=1000, solver=sgd; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(10,), learning_rate=adaptive, max_iter=1000, solver=sgd; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(10,), learning_rate=adaptive, max_iter=1000, solver=sgd; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(10,), learning_rate=adaptive, max_iter=1000, solver=sgd; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(10,), learning_rate=adaptive, max_iter=1000, solver=sgd; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(10,), learning_rate=adaptive, max_iter=5000, solver=adam; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(10,), learning_rate=adaptive, max_iter=5000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(10,), learning_rate=adaptive, max_iter=5000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(10,), learning_rate=adaptive, max_iter=5000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(10,), learning_rate=adaptive, max_iter=5000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(10,), learning_rate=adaptive, max_iter=5000, solver=sgd; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(10,), learning_rate=adaptive, max_iter=5000, solver=sgd; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(10,), learning_rate=adaptive, max_iter=5000, solver=sgd; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(10,), learning_rate=adaptive, max_iter=5000, solver=sgd; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(10,), learning_rate=adaptive, max_iter=5000, solver=sgd; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(10,), learning_rate=adaptive, max_iter=10000, solver=adam; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(10,), learning_rate=adaptive, max_iter=10000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(10,), learning_rate=adaptive, max_iter=10000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(10,), learning_rate=adaptive, max_iter=10000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(10,), learning_rate=adaptive, max_iter=10000, solver=adam; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(10,), learning_rate=adaptive, max_iter=10000, solver=sgd; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(10,), learning_rate=adaptive, max_iter=10000, solver=sgd; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(10,), learning_rate=adaptive, max_iter=10000, solver=sgd; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(10,), learning_rate=adaptive, max_iter=10000, solver=sgd; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(10,), learning_rate=adaptive, max_iter=10000, solver=sgd; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=constant, max_iter=1000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=constant, max_iter=1000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=constant, max_iter=1000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=constant, max_iter=1000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=constant, max_iter=1000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=constant, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=constant, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=constant, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=constant, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=constant, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=constant, max_iter=5000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=constant, max_iter=5000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=constant, max_iter=5000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=constant, max_iter=5000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=constant, max_iter=5000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=constant, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=constant, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=constant, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=constant, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=constant, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=constant, max_iter=10000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=constant, max_iter=10000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=constant, max_iter=10000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=constant, max_iter=10000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=constant, max_iter=10000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=constant, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=constant, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=constant, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=constant, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=constant, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=invscaling, max_iter=1000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=invscaling, max_iter=1000, solver=adam; total time=   0.3s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=invscaling, max_iter=1000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=invscaling, max_iter=1000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=invscaling, max_iter=1000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=invscaling, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=invscaling, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=invscaling, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=invscaling, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=invscaling, max_iter=1000, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=invscaling, max_iter=5000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=invscaling, max_iter=5000, solver=adam; total time=   0.3s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=invscaling, max_iter=5000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=invscaling, max_iter=5000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=invscaling, max_iter=5000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=invscaling, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=invscaling, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=invscaling, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=invscaling, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=invscaling, max_iter=5000, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=invscaling, max_iter=10000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=invscaling, max_iter=10000, solver=adam; total time=   0.3s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=invscaling, max_iter=10000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=invscaling, max_iter=10000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=invscaling, max_iter=10000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=invscaling, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=invscaling, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=invscaling, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=invscaling, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=invscaling, max_iter=10000, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=adaptive, max_iter=1000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=adaptive, max_iter=1000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=adaptive, max_iter=1000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=adaptive, max_iter=1000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=adaptive, max_iter=1000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=adaptive, max_iter=1000, solver=sgd; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=adaptive, max_iter=1000, solver=sgd; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=adaptive, max_iter=1000, solver=sgd; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=adaptive, max_iter=1000, solver=sgd; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=adaptive, max_iter=1000, solver=sgd; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=adaptive, max_iter=5000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=adaptive, max_iter=5000, solver=adam; total time=   0.3s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=adaptive, max_iter=5000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=adaptive, max_iter=5000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=adaptive, max_iter=5000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=adaptive, max_iter=5000, solver=sgd; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=adaptive, max_iter=5000, solver=sgd; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=adaptive, max_iter=5000, solver=sgd; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=adaptive, max_iter=5000, solver=sgd; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=adaptive, max_iter=5000, solver=sgd; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=adaptive, max_iter=10000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=adaptive, max_iter=10000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=adaptive, max_iter=10000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=adaptive, max_iter=10000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=adaptive, max_iter=10000, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=adaptive, max_iter=10000, solver=sgd; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=adaptive, max_iter=10000, solver=sgd; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=adaptive, max_iter=10000, solver=sgd; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=adaptive, max_iter=10000, solver=sgd; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(20,), learning_rate=adaptive, max_iter=10000, solver=sgd; total time=   0.1s
# Best parameters: {'activation': 'tanh', 'hidden_layer_sizes': (20,), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'adam'}
# Best cross-validated score: 0.6684563758389261
# Test accuracy: 0.6375
# Confusion matrix:
#  [[ 96  66]
#  [ 50 108]]
